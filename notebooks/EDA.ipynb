# %%
import numpy as np
import pandas as pd
from datetime import datetime
import plotly.express as px

# %% [markdown]
# # Pre-Explortion

# %%
df_BTC = pd.read_csv('../data/raw/BTC-USD (2014-2024).csv')

# %%
df_ETH = pd.read_csv("../data/raw/ETH-USD (2017-2024).csv")

# %%
df_BTC.describe()
# Out:
#                Open          High           Low         Close     Adj Close  \
# count   3413.000000   3413.000000   3413.000000   3413.000000   3413.000000
# mean   14755.235325  15099.657349  14384.058077  14765.995800  14765.995800
# std    16297.740573  16687.803094  15860.348001  16299.494608  16299.494608
# min      176.897003    211.731003    171.509995    178.102997    178.102997
# 25%      922.067017    937.525024    910.416992    921.789001    921.789001
# 50%     8290.759766   8470.988281   8110.770020   8293.868164   8293.868164
# 75%    24373.457031  25020.458984  23927.910156  24402.818359  24402.818359
# max    67549.734375  68789.625000  66382.062500  67566.828125  67566.828125
#
#              Volume
# count  3.413000e+03
# mean   1.662879e+10
# std    1.907347e+10
# min    5.914570e+06
# 25%    1.689680e+08
# 50%    1.171838e+10
# 75%    2.696772e+10
# max    3.509679e+11

# %%
df_BTC.shape
# Out:
# (3413, 7)

# %%
df_BTC['Date'] = pd.to_datetime(df_BTC['Date'])

# %%
df_BTC['price_change_per_day'] = df_BTC['Close'] - df_BTC['Open']

# %%
df_BTC['price_change_ratio_per_day'] = (df_BTC['Close'] - df_BTC['Open'])/df_BTC['Open']

# %%
df_BTC.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3413 entries, 0 to 3412
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        3413 non-null   datetime64[ns]
#  1   Open                        3413 non-null   float64
#  2   High                        3413 non-null   float64
#  3   Low                         3413 non-null   float64
#  4   Close                       3413 non-null   float64
#  5   Adj Close                   3413 non-null   float64
#  6   Volume                      3413 non-null   int64
#  7   price_change_per_day        3413 non-null   float64
#  8   price_change_ratio_per_day  3413 non-null   float64
# dtypes: datetime64[ns](1), float64(7), int64(1)
# memory usage: 240.1 KB

# %%
df_BTC.head()
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2014-09-18  456.859985  456.859985  413.104004  424.440002  424.440002
# 1 2014-09-19  424.102997  427.834991  384.532013  394.795990  394.795990
# 2 2014-09-20  394.673004  423.295990  389.882996  408.903992  408.903992
# 3 2014-09-21  408.084991  412.425995  393.181000  398.821014  398.821014
# 4 2014-09-22  399.100006  406.915985  397.130005  402.152008  402.152008
#
#      Volume  price_change_per_day  price_change_ratio_per_day
# 0  34483200            -32.419983                   -0.070963
# 1  37919700            -29.307007                   -0.069104
# 2  36863600             14.230988                    0.036058
# 3  26580100             -9.263977                   -0.022701
# 4  24127600              3.052002                    0.007647

# %%
df_ETH.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  2264.000000  2264.000000  2264.000000  2264.000000  2264.000000
# mean   1248.761566  1284.505020  1209.402447  1249.509584  1249.509584
# std    1118.892650  1150.947388  1082.638995  1118.613103  1118.613103
# min      84.279694    85.342743    82.829887    84.308296    84.308296
# 25%     231.642361   236.876278   227.209290   232.001541   232.001541
# 50%    1039.842713  1091.724976   961.066497  1039.666504  1039.666504
# 75%    1871.261627  1905.404876  1845.200562  1872.125305  1872.125305
# max    4810.071289  4891.704590  4718.039063  4812.087402  4812.087402
#
#              Volume
# count  2.264000e+03
# mean   1.204945e+10
# std    1.012319e+10
# min    6.217330e+08
# 25%    4.845994e+09
# 50%    9.394469e+09
# 75%    1.656983e+10
# max    8.448291e+10

# %%
df_ETH.shape
# Out:
# (2264, 7)

# %%
df_ETH.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2017-11-10  320.670990  324.717987  294.541992  299.252991  299.252991
# 1  2017-11-11  298.585999  319.453003  298.191986  314.681000  314.681000
# 2  2017-11-12  314.690002  319.153015  298.513000  307.907990  307.907990
# 3  2017-11-13  307.024994  328.415009  307.024994  316.716003  316.716003
# 4  2017-11-14  316.763000  340.177002  316.763000  337.631012  337.631012
#
#        Volume
# 0   885985984
# 1   842300992
# 2  1613479936
# 3  1041889984
# 4  1069680000

# %%
df_ETH['Date'] = pd.to_datetime(df_ETH['Date'])

# %%
df_ETH['price_change_per_day'] = df_ETH['Close'] - df_ETH['Open']

# %%
df_ETH['price_change_ratio_per_day'] = (df_ETH['Close'] - df_ETH['Open'])/df_ETH['Open']

# %%
df_ETH.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2264 entries, 0 to 2263
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        2264 non-null   datetime64[ns]
#  1   Open                        2264 non-null   float64
#  2   High                        2264 non-null   float64
#  3   Low                         2264 non-null   float64
#  4   Close                       2264 non-null   float64
#  5   Adj Close                   2264 non-null   float64
#  6   Volume                      2264 non-null   int64
#  7   price_change_per_day        2264 non-null   float64
#  8   price_change_ratio_per_day  2264 non-null   float64
# dtypes: datetime64[ns](1), float64(7), int64(1)
# memory usage: 159.3 KB

# %%
df_ETH.head()
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2017-11-10  320.670990  324.717987  294.541992  299.252991  299.252991
# 1 2017-11-11  298.585999  319.453003  298.191986  314.681000  314.681000
# 2 2017-11-12  314.690002  319.153015  298.513000  307.907990  307.907990
# 3 2017-11-13  307.024994  328.415009  307.024994  316.716003  316.716003
# 4 2017-11-14  316.763000  340.177002  316.763000  337.631012  337.631012
#
#        Volume  price_change_per_day  price_change_ratio_per_day
# 0   885985984            -21.417999                   -0.066791
# 1   842300992             16.095001                    0.053904
# 2  1613479936             -6.782012                   -0.021551
# 3  1041889984              9.691009                    0.031564
# 4  1069680000             20.868012                    0.065879

# %% [markdown]
# # Visualization

# %%
fig_BTC = px.line(df_BTC, x='Date', y='Close', title='Time Series Plot of BTC', labels={'Close': 'Close Price'})

fig_BTC

# %%
fig_BTC_change = px.line(df_BTC, x='Date', y='price_change_per_day', title='Time Series Plot of BTC price change per day', labels={'price_change_per_day': 'price change per day'})

fig_BTC_change

# %%
fig_BTC_ratio = px.line(df_BTC, x='Date', y='price_change_ratio_per_day', title='Time Series Plot of BTC price change ratio per day', labels={'price_change_ratio_per_day': 'price change ratio per day'})

fig_BTC_ratio

# %%
fig_ETH = px.line(df_ETH, x='Date', y='Close', title='Time Series Plot of ETH', labels={'Close': 'Close Price'})

fig_ETH

# %%
fig_ETH_change = px.line(df_ETH, x='Date', y='price_change_per_day', title='Time Series Plot of ETH price change per day', labels={'price_change_per_day': 'price change per day'})

fig_ETH_change

# %%
fig_ETH_ratio = px.line(df_ETH, x='Date', y='price_change_ratio_per_day', title='Time Series Plot of ETH price change ratio per day', labels={'price_change_ratio_per_day': 'price change ratio per day'})

fig_ETH_ratio

# %%
# df_BTC.to_csv('BTC.csv', index=False)

# %%
# df_ETH.to_csv('ETH.csv', index=False)
